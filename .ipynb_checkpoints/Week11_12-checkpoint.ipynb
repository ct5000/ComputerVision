# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from scipy.spatial.transform import Rotation

# %%
#Setup
K = np.loadtxt('Glyp/K.txt')
im1 = cv2.imread('Glyp/sequence/000001.png')
im1 = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY)
im2 = cv2.imread('Glyp/sequence/000002.png')
im2 = cv2.cvtColor(im2, cv2.COLOR_BGR2GRAY)
im3 = cv2.imread('Glyp/sequence/000003.png')
im3 = cv2.cvtColor(im3, cv2.COLOR_BGR2GRAY)

fig = plt.figure(figsize = (20,20))
fig.add_subplot(1,3,1)
plt.imshow(im1,cmap='gray')
fig.add_subplot(1,3,2)
plt.imshow(im2,cmap='gray')
fig.add_subplot(1,3,3)
plt.imshow(im3,cmap='gray')

# %%
# Exercise 11.1
sift = cv2.SIFT_create(2000)
kp1_o, des1 = sift.detectAndCompute(im1,None)
kp2_o, des2 = sift.detectAndCompute(im2,None)
kp3_o, des3 = sift.detectAndCompute(im3,None)


kp1 = np.array([k.pt for k in kp1_o])
kp2 = np.array([k.pt for k in kp2_o])
kp3 = np.array([k.pt for k in kp3_o])

bf = cv2.BFMatcher()

matches1_2_o = bf.match(des1,des2)
matches1_2 = sorted(matches1_2_o, key = lambda x:x.distance)

matches1_2 = np.array([(m.queryIdx, m.trainIdx) for m in matches1_2])

matches2_3_o = bf.match(des2,des3)
matches2_3 = sorted(matches2_3_o, key = lambda x:x.distance)

matches2_3 = np.array([(m.queryIdx, m.trainIdx) for m in matches2_3])

im1_2 = cv2.drawMatches(im1,kp1_o,im2,kp2_o,matches1_2_o,None)
im2_3 = cv2.drawMatches(im2,kp2_o,im3,kp3_o,matches2_3_o,None)

fig = plt.figure(figsize = (20,20))
fig.add_subplot(1,2,1)
plt.imshow(im1_2)
fig.add_subplot(1,2,2)
plt.imshow(im2_3)

# %%
print(len(matches1_2))
print(kp1[matches1_2[:,0]])
print(kp2[matches1_2[:,1]])
print(kp1[matches1_2[:,0]]-kp2[matches1_2[:,1]])
# Out:
# 754
# [[1042.77099609  479.18960571]
#  [1313.68432617  461.92907715]
#  [1257.61669922   79.93842316]
#  ...
#  [ 573.36383057 1568.06884766]
#  [ 141.24734497  611.62902832]
#  [ 130.14796448  601.00109863]]
# [[1147.6439209   607.19799805]
#  [1424.55871582  592.7053833 ]
#  [1355.82971191  212.80535889]
#  ...
#  [1671.77416992 1747.13598633]
#  [ 273.23791504  724.08032227]
#  [ 285.63034058  711.15411377]]
# [[ -104.8729248   -128.00839233]
#  [ -110.87438965  -130.77630615]
#  [  -98.2130127   -132.86693573]
#  ...
#  [-1098.41033936  -179.06713867]
#  [ -131.99057007  -112.45129395]
#  [ -155.4823761   -110.15301514]]

# %%
# Exercises 11.2

E1_2, mask = cv2.findEssentialMat(kp1[matches1_2[:,0]],kp2[matches1_2[:,1]],K,method=cv2.RANSAC)
print("E1_2",E1_2)
idx = [i for i, e in enumerate(mask) if e != 0]
matches1_2 = matches1_2[idx]
retval, R2,t2,mask = cv2.recoverPose(E1_2,kp1[matches1_2[:,0]],kp2[matches1_2[:,1]],K)
idx = [i for i, e in enumerate(mask) if e != 0]
print("before", len(matches1_2))
matches1_2 = matches1_2[idx]
print("after", len(matches1_2))
print("R2",R2)
print("t2",t2)
# Out:
# E1_2 [[ 0.00175716  0.27265767 -0.03625206]
#  [-0.27987262  0.03352867 -0.64662213]
#  [ 0.05517933  0.65022726  0.03045013]]
# before 761
# after 754
# R2 [[ 0.99985684 -0.00839681 -0.01469015]
#  [ 0.00909115  0.99881289  0.04785562]
#  [ 0.01427088 -0.04798232  0.99874623]]
# t2 [[ 0.92123883]
#  [-0.0696702 ]
#  [-0.38270755]]

# %%
# Exercise 11.3

_, idx12, idx23 = np.intersect1d(matches1_2[:,1],matches2_3[:,0],return_indices = True)

print(len(idx12))

points1 = kp1[matches1_2[idx12,0]]
points2 = kp2[matches2_3[idx23,0]]
points3 = kp3[matches2_3[idx23,1]]

fig = plt.figure(figsize = (20,20))
ax1 = fig.add_subplot(1,3,1)
plt.imshow(im1,cmap='gray')
ax1.scatter(points1[:,0],points1[:,1],s=2)
ax2 = fig.add_subplot(1,3,2)
plt.imshow(im2,cmap='gray')
ax2.scatter(points2[:,0],points2[:,1],s=2)
ax3 = fig.add_subplot(1,3,3)
plt.imshow(im3,cmap='gray')
ax3.scatter(points3[:,0],points3[:,1],s=2)
# Out:
# 732

# %%
def triangulate(points,projection):
    point_h = points[0]
    point = point_h[:-1] / point_h[-1]
    B = projection[0][2,:] * point[0] - projection[0][0,:]
    B = np.vstack([B, projection[0][2,:] * point[1] - projection[0][1,:]])
    for i in range(1,len(points)):
        point_h = points[i]
        point = point_h[:-1] / point_h[-1]
        B = np.vstack([B, projection[i][2,:] * point[0] - projection[i][0,:]])
        B = np.vstack([B, projection[i][2,:] * point[1] - projection[i][1,:]])
    _,_,VT = np.linalg.svd(B)
    Q = VT[-1,:]
    Q.reshape(4,1)
    return Q

def triangulate_points(q1,q2,P1,P2):
    Q_est = np.zeros((3,q1.shape[1]))
    for i in range(q1.shape[1]):
        if q1[2,i] == 0 or q2[2,i] == 0:
            continue
        #print(np.hstack([q1[:,i].reshape(3,1),q2[:,i].reshape(3,1)]))
        Q_tr_h = triangulate([q1[:,i],q2[:,i]],[P1,P2])
        #Q_tr = triangulate(np.hstack([q1[:,i].reshape(3,1),q2[:,i].reshape(3,1)]),[P1,P2])
        #print(Q_tr.shape)
        Q_tr = Q_tr_h[:-1] / Q_tr_h[-1]
        Q_est[:,i] = Q_tr
    return Q_est

# %%
# Exercise 11.4

P1 = K@np.hstack([np.identity(3), np.array([[0,0,0]]).T])
#P1 = K@np.hstack([R2.T, -R2.T@t2])
P2 = K@np.hstack([R2,t2])
print(P1)
print(P2)
#points1_h = np.vstack([points1.T,np.ones([1,points1.shape[0]])])
#points2_h = np.vstack([points2.T,np.ones([1,points2.shape[0]])])
#Q = triangulate_points(points1_h,points2_h,P1,P2)
Q = cv2.triangulatePoints(P1,P2,points1.T,points2.T)
Q = Q[:-1]/Q[-1]
print(Q.shape)
# Out:
# [[3.1174740e+03 0.0000000e+00 1.5019408e+03 0.0000000e+00]
#  [0.0000000e+00 3.1174740e+03 9.8476840e+02 0.0000000e+00]
#  [0.0000000e+00 0.0000000e+00 1.0000000e+00 0.0000000e+00]]
# [[ 3.13751916e+03 -9.81451382e+01  1.45630057e+03  2.31801441e+03]
#  [ 4.20448903e+01  3.06689078e+03  1.13173588e+03 -5.80207961e+02]
#  [ 1.36263971e-02 -4.76539458e-02  9.98770956e-01 -3.75380855e-01]]
# (3, 725)

# %%
distCoeffs = np.zeros(5)
retval, rvec,tvec,inliers = cv2.solvePnPRansac(Q.T,points3,K,distCoeffs)
print(tvec)
# Out:
# [[ 1.99861846]
#  [-0.25991858]
#  [-1.05501201]]

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(Q[0,inliers],Q[1,inliers],Q[2,inliers])

# %%
retval, rvec1,tvec1,inliers1 = cv2.solvePnPRansac(Q.T,points1,K,distCoeffs)
retval, rvec2,tvec2,inliers2 = cv2.solvePnPRansac(Q.T,points2,K,distCoeffs)

# %%
CamPos = np.zeros([3,3])
RotMat1 = Rotation.from_euler('xyz',rvec1.T).as_matrix()[0,:]
#t1 = np.array([[0,0,0]]).T
CamPos[:,0] = -RotMat1.T@tvec1[:,0]
RotMat2 = Rotation.from_euler('xyz',rvec2.T).as_matrix()[0,:]
CamPos[:,1] = (-RotMat2.T@tvec2)[:,0]
RotMat3 = Rotation.from_euler('xyz',rvec.T).as_matrix()[0,:]
CamPos[:,2] = -RotMat3.T@tvec[:,0]
#print(tvec.T)
#print(Rotation.from_euler('xyz',tvec.T).as_matrix())
#CamPos[:,1] = -rvec2.T@(Rotation.from_euler('xyz',tvec2.T).as_matrix())
#CamPos[:,2] = -rvec.T@(Rotation.from_euler('xyz',tvec.T).as_matrix())

print(CamPos)
# Out:
# [[ 1.88397590e-04 -9.18589166e-01 -1.96737043e+00]
#  [-4.40772615e-04  5.76570842e-02  1.71522167e-01]
#  [-1.93250065e-04  3.91520631e-01  1.12921100e+00]]

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(CamPos[0,:],CamPos[1,:],CamPos[2,:])

# %%
fig = plt.figure()
ax1 = fig.add_subplot(1,3,1)
ax1.scatter([0,1,2],CamPos[0,:])
ax2 = fig.add_subplot(1,3,2)
ax2.scatter([0,1,2],CamPos[1,:])
ax3 = fig.add_subplot(1,3,3)
ax3.scatter([0,1,2],CamPos[2,:])

# %%
# Exercise 11.5
ims = []
K = np.loadtxt('Glyp/K.txt')
for i in range(1,21):   
    im = cv2.imread('Glyp/sequence/0000%02d.png' % i)
    im = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
    ims.append(im)


fig = plt.figure(figsize = (20,20))
fig.add_subplot(1,3,1)
plt.imshow(ims[15],cmap='gray')
fig.add_subplot(1,3,2)
plt.imshow(ims[16],cmap='gray')
fig.add_subplot(1,3,3)
plt.imshow(ims[17],cmap='gray')

# %% [markdown]
# # Attempt 1

# %%
kps = []
dess = []
sift = cv2.SIFT_create(2000)

for im in ims:
    kp, des = sift.detectAndCompute(im,None)
    kp = np.array([k.pt for k in kp])
    kps.append(kp)
    dess.append(des)

# %%
matchess = []
bf = cv2.BFMatcher()

for i in range(0,len(kps)-1):
    matches = bf.match(dess[i],dess[i+1])
    matches = sorted(matches, key = lambda x:x.distance)
    matches = np.array([(m.queryIdx, m.trainIdx) for m in matches])
    matchess.append(matches)

Rs = []
ts = []
R1 = np.identity(3)
t1 = np.zeros((3,1))
Rs.append(R1)
ts.append(t1)
Es = []

for i in range(0,len(matchess)):
    E, mask = cv2.findEssentialMat(kps[i][matchess[i][:,0]],kps[i+1][matchess[i][:,1]],K,method=cv2.RANSAC)
    Es.append(E)
    idx = [j for j, e in enumerate(mask) if e != 0]
    matchess[i] = matchess[i][idx]
    retval, R,t,mask = cv2.recoverPose(E,kps[i][matchess[i][:,0]],kps[i+1][matchess[i][:,1]],K)
    idx = [j for j, e in enumerate(mask) if e != 0]
    matchess[i] = matchess[i][idx]
    Rs.append(R)
    ts.append(t)

# %%
pointss = []
idxs = []

for i in range(len(matchess)-1):
    _, idx1, idx2 = np.intersect1d(matchess[i][:,1],matchess[i+1][:,0],return_indices = True)
    points1 = kp1[matchess[i][idx1,0]]
    points2 = kp2[matchess[i+1][idx2,0]]
    points3 = kp3[matchess[i+1][idx2,1]]
    points = [points1,points2,points3]
    pointss.append(points)

# %%
Ps = []
Qs = []
ts_abs = []
Rs_abs = []
distCoeffs = np.zeros(5)

for i in range(len(pointss)):
    P1 = K@np.hstack([Rs[i], ts[i]])
    P2 = K@np.hstack([Rs[i+1],ts[i+1]])
    Ps.append(P1)
    Q = cv2.triangulatePoints(P1,P2,pointss[i][0].T,pointss[i][1].T)
    Q = Q[:-1]/Q[-1]
    Qs.append(Q)
    retval, rvec,tvec,inliers = cv2.solvePnPRansac(Q.T,points3,K,distCoeffs)

# %%
_, idx12, idx23 = np.intersect1d(matches1_2[:,1],matches2_3[:,0],return_indices = True)

points1 = kp1[matches1_2[idx12,0]]
points2 = kp2[matches2_3[idx23,0]]
points3 = kp3[matches2_3[idx23,1]]


Q = cv2.triangulatePoints(P1,P2,points1.T,points2.T)
Q = Q[:-1]/Q[-1]

# %%
print(len(matchess))
print(len(kps))
# Out:
# 19
# 20

# %% [markdown]
# # Attempt 2

# %%
# Trying again different approach
# First 3 images
sift = cv2.SIFT_create(2000)
kp1, des1 = sift.detectAndCompute(im1,None)
kp2, des2 = sift.detectAndCompute(im2,None)
kp3, des3 = sift.detectAndCompute(im3,None)


kp1 = np.array([k.pt for k in kp1])
kp2 = np.array([k.pt for k in kp2])
kp3 = np.array([k.pt for k in kp3])

bf = cv2.BFMatcher()

matches1_2 = bf.match(des1,des2)
matches1_2 = sorted(matches1_2, key = lambda x:x.distance)
matches1_2 = np.array([(m.queryIdx, m.trainIdx) for m in matches1_2])

matches2_3 = bf.match(des2,des3)
matches2_3 = sorted(matches2_3, key = lambda x:x.distance)
matches2_3 = np.array([(m.queryIdx, m.trainIdx) for m in matches2_3])


E1_2, mask = cv2.findEssentialMat(kp1[matches1_2[:,0]],kp2[matches1_2[:,1]],K,method=cv2.RANSAC)
idx = [i for i, e in enumerate(mask) if e != 0]
matches1_2 = matches1_2[idx]

retval, R2,t2,mask = cv2.recoverPose(E1_2,kp1[matches1_2[:,0]],kp2[matches1_2[:,1]],K)
idx = [i for i, e in enumerate(mask) if e != 0]
matches1_2 = matches1_2[idx]

_, idx12, idx23 = np.intersect1d(matches1_2[:,1],matches2_3[:,0],return_indices = True)

points1 = kp1[matches1_2[idx12,0]]
points2 = kp2[matches2_3[idx23,0]]
points3 = kp3[matches2_3[idx23,1]]
valid_des3 = des3[matches2_3[idx23,1]]

P1 = K@np.hstack([np.identity(3), np.array([[0,0,0]]).T])
P2 = K@np.hstack([R2,t2])

Q = cv2.triangulatePoints(P1,P2,points1.T,points2.T)
Q = Q[:-1]/Q[-1]

distCoeffs = np.zeros(5)
retval, rvec,tvec,inliers = cv2.solvePnPRansac(Q.T,points3,K,distCoeffs)

RotMat3 = Rotation.from_euler('xyz',rvec.T).as_matrix()[0,:]
P3 = K@np.hstack([RotMat3, tvec])

# %%
# Rest

prev_des = valid_des3.copy()
prev_points = points3.copy()
prev_frame = ims[2]
P_prev = P3.copy()
Q_prev = Q.copy()
Qs = [Q]
ts = [tvec]
Rs = [RotMat]

for i in tqdm(range(3,len(ims))):
    current_im = ims[i]
    cur_kp, cur_des = sift.detectAndCompute(current_im,None)
    cur_kp = np.array([k.pt for k in cur_kp])
    
    matches = bf.match(prev_des,cur_des)
    matches = sorted(matches, key = lambda x:x.distance)
    matches = np.array([(m.queryIdx, m.trainIdx) for m in matches])
    
    prev_idx = matches[:,0]
    cur_idx = matches[:,1]
    
    Q_prev_trans = Q_prev[:,prev_idx]
    new_trans = cur_kp[new_idx,:].astype(np.float32)
    
    _, rvec, tvec, inliers = cv2.solvePnPRansac(Q_prev_trans.T, new_trans, K, None)
    
    RotMat = Rotation.from_euler('xyz',rvec.T).as_matrix()[0,:]
    
    P_new = K@np.hstack([RotMat,tvec])
    
    #prev_kp, prev_des = sift.detectAndCompute(prev_im,None)
    #prev_kp = np.array([k.pt for k in prev_kp])
    
    E, mask = cv2.findEssentialMat(cur_kp[matches[:,0]],cur_kp[matches[:,1]],K,method=cv2.RANSAC)
    idx = [j for j, e in enumerate(mask) if e != 0]
    matches = matchess[i][idx]
    retval, R,t,mask = cv2.recoverPose(E,cur_kp[matches[:,0]],cur_kp[matches[:,1]],K)
    idx = [j for j, e in enumerate(mask) if e != 0]
    matches = matchess[i][idx]

# %% [markdown]
# # Attempt 3

# %%
def match_sift(des1, des2, KNN_matcher=False):
    """
    Match stuff
    """
    bf = cv2.BFMatcher() #crossCheck=True
    if KNN_matcher:
        knn_matches = bf.knnMatch(des1, des2, k=2)
        # Ratio test!
        ratio_matches = []
        for m,n in knn_matches:
            if m.distance < 0.75*n.distance:
                ratio_matches.append(m)
        
        # Return the keypoint indexes of matches 
        return np.array([(m.queryIdx, m.trainIdx) for m in ratio_matches])
    else:
        all_matches = bf.match(des1, des2)
        #sorted_matches = sorted(matches, key = lambda x:x.distance)
        return np.array([(m.queryIdx, m.trainIdx) for m in all_matches])

# %%
#This part is a general 

kps = []
kps_o = []
dess = []
sift = cv2.SIFT_create(2000)

for im in ims:
    kp, des = sift.detectAndCompute(im,None)
    kps_o.append(kp)
    kp = np.array([k.pt for k in kp])
    kps.append(kp)
    dess.append(des)
    
    
matchess = []
matchess_o = []
bf = cv2.BFMatcher()

for i in range(0,len(kps)-1):
    
    matches = bf.match(dess[i],dess[i+1])
    matches = sorted(matches, key = lambda x:x.distance)
    matchess_o.append(matches)
    matches = np.array([(m.queryIdx, m.trainIdx) for m in matches])
    
    #matches = match_sift(dess[i],dess[i+1],KNN_matcher=True)
    matchess.append(matches)

Rs_relative = []
ts_relative = []
R0 = np.identity(3)
t0 = np.zeros((3,1))
#Rs.append(R1)
#ts.append(t1)
Es = []



for i in range(0,len(matchess)):
    E, mask = cv2.findEssentialMat(kps[i][matchess[i][:,0]],kps[i+1][matchess[i][:,1]],K,method=cv2.RANSAC)
    Es.append(E)
    idx = [j for j, e in enumerate(mask) if e != 0]
    matchess[i] = matchess[i][idx]
    #matchess_o[i] = matchess_o[i][idx]
    retval, R,t,mask = cv2.recoverPose(E,kps[i][matchess[i][:,0]],kps[i+1][matchess[i][:,1]],K)
    idx = [j for j, e in enumerate(mask) if e != 0]
    matchess[i] = matchess[i][idx]
    #matchess_o[i] = matchess_o[i][idx]
    Rs_relative.append(R)
    ts_relative.append(t)

'''

E, mask = cv2.findEssentialMat(kps[0][matchess[0][:,0]],kps[1][matchess[0][:,1]],K,method=cv2.RANSAC)
Es.append(E)
idx = [j for j, e in enumerate(mask) if e != 0]
matchess[0] = matchess[0][idx]
#matchess_o[i] = matchess_o[i][idx]
retval, R,t,mask = cv2.recoverPose(E,kps[0][matchess[0][:,0]],kps[1][matchess[0][:,1]],K)
idx = [j for j, e in enumerate(mask) if e != 0]
matchess[0] = matchess[0][idx]
#matchess_o[i] = matchess_o[i][idx]
Rs_relative.append(R)
ts_relative.append(t)

'''
# Out:
# '\n\nE, mask = cv2.findEssentialMat(kps[0][matchess[0][:,0]],kps[1][matchess[0][:,1]],K,method=cv2.RANSAC)\nEs.append(E)\nidx = [j for j, e in enumerate(mask) if e != 0]\nmatchess[0] = matchess[0][idx]\n#matchess_o[i] = matchess_o[i][idx]\nretval, R,t,mask = cv2.recoverPose(E,kps[0][matchess[0][:,0]],kps[1][matchess[0][:,1]],K)\nidx = [j for j, e in enumerate(mask) if e != 0]\nmatchess[0] = matchess[0][idx]\n#matchess_o[i] = matchess_o[i][idx]\nRs_relative.append(R)\nts_relative.append(t)\n\n'

# %%
for match in matchess:
    print(len(match))



'''
im1_2 = cv2.drawMatches(ims[15],kps_o[15],ims[16],kps_o[16],matchess_o[15],None)
im2_3 = cv2.drawMatches(ims[16],kps_o[16],ims[17],kps_o[17],matchess_o[16],None)

fig = plt.figure(figsize = (20,20))
fig.add_subplot(1,2,1)
plt.imshow(im1_2)
fig.add_subplot(1,2,2)
plt.imshow(im2_3)

print(len(matchess_o[16]))
'''
# Out:
# 754
# 553
# 562
# 880
# 640
# 561
# 621
# 547
# 525
# 313
# 497
# 718
# 519
# 89
# 128
# 433
# 44
# 69
# 41
# '\nim1_2 = cv2.drawMatches(ims[15],kps_o[15],ims[16],kps_o[16],matchess_o[15],None)\nim2_3 = cv2.drawMatches(ims[16],kps_o[16],ims[17],kps_o[17],matchess_o[16],None)\n\nfig = plt.figure(figsize = (20,20))\nfig.add_subplot(1,2,1)\nplt.imshow(im1_2)\nfig.add_subplot(1,2,2)\nplt.imshow(im2_3)\n\nprint(len(matchess_o[16]))\n'

# %%
Ps = []
P0 = K@np.hstack([R0,t0])
Ps.append(P0)
#P1 = K@np.hstack([Rs_relative[0],ts_relative[0]])
P1 = K@np.hstack([R2,t2])
Ps.append(P1)
Position = np.zeros((3,len(ims)))
#Position[:,1] = (-Rs_relative[0].T@ts_relative[0])[:,0]
Position[:,1] = -R2.T@t2[:,0]
Qs = np.array([[0,0,0]]).T


for i in range(1,len(ims)-1):
    #print(i)
    _, idx1, idx2 = np.intersect1d(matchess[i-1][:,1],matchess[i][:,0],return_indices = True)
    #print("match 1 len ", len(matchess[i-1]),"match 2 len ", len(matchess[i]),"idx:", len(idx1), "i", i)
    if len(idx1) < 5:
        print("Faults")
        continue
    points1 = kps[i-1][matchess[i-1][idx1,0]]
    points2 = kps[i][matchess[i][idx2,0]]
    points3 = kps[i+1][matchess[i][idx2,1]]
    
    P1 = Ps[i-1]
    P2 = Ps[i]
    
    Q_h = cv2.triangulatePoints(P1,P2,points1.T,points2.T)
    Q = Q_h[:-1]/Q_h[-1]
    Qs = np.hstack([Qs,Q])

    distCoeffs = np.zeros(5)
    retval, rvec,tvec,inliers = cv2.solvePnPRansac(Q.T,points3,K,distCoeffs)

    RotMat3 = Rotation.from_euler('xyz',rvec.T).as_matrix()[0,:]
    P3 = K@np.hstack([RotMat3, tvec])
    #print(np.hstack([RotMat3, tvec]))
    Ps.append(P3)
    Pos_to_add = (-RotMat3.T@tvec)[:,0]
    #print("Pos", Pos_to_add)
    Position[:,i+1] = Pos_to_add
# Out:
# Faults
# Faults
# Faults

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(Position[0,:17],Position[1,:17],Position[2,:17])

# %%
print(Position.T)
# Out:
# [[  0.           0.           0.        ]
#  [ -0.91501199   0.05895977   0.39909498]
#  [ -1.93010136   0.1669092    1.12872393]
#  [ -3.38323349   0.26779025   2.03993214]
#  [ -4.39099509   0.33716583   2.78440029]
#  [ -5.42846497   0.335253     3.32788011]
#  [ -6.91601733   0.29513627   4.16585354]
#  [ -7.96792506   0.11304265   4.39428366]
#  [ -9.33936674  -0.23395604   5.55258193]
#  [ -7.38930766  -5.16689133   4.641666  ]
#  [ -8.91409306   0.22651668   4.60296922]
#  [ -8.59159721   0.72718846   4.01014292]
#  [-19.29461887   7.32643538   5.90350368]
#  [ -7.38659169   9.30433135  -0.15174474]
#  [-13.30789683   6.84809134 -13.74030422]
#  [ -9.99424759  43.95159367 -22.74013035]
#  [ -7.46995085  15.49802967 -12.63908348]
#  [  0.           0.           0.        ]
#  [  0.           0.           0.        ]
#  [  0.           0.           0.        ]]

# %%
fig = plt.figure()
x_axis = np.arange(0,Position.shape[1]-3)
ax1 = fig.add_subplot(1,3,1)
ax1.scatter(x_axis,Position[0,:17])
ax2 = fig.add_subplot(1,3,2)
ax2.scatter(x_axis,Position[1,:17])
ax3 = fig.add_subplot(1,3,3)
ax3.scatter(x_axis,Position[2,:17])

# %%
fig = plt.figure()

ax1 = fig.add_subplot(1,3,1)
ax1.scatter(Position[0,:17],Position[1,:17])
ax2 = fig.add_subplot(1,3,2)
ax2.scatter(Position[0,:17],Position[2,:17])
ax3 = fig.add_subplot(1,3,3)
ax3.scatter(Position[1,:17],Position[2,:17])

# %%
Qs_filt = Qs[:,np.abs(Qs[0,:])<15]
Qs_filt = Qs_filt[:,np.abs(Qs_filt[1,:])<15]
Qs_filt = Qs_filt[:,np.abs(Qs_filt[2,:])<60]


fig = plt.figure(figsize=(30,30))
ax = fig.add_subplot(projection='3d')
ax.scatter(Qs_filt[0,1:],Qs_filt[1,1:],Qs_filt[2,1:],s=2)
ax.view_init(90,90)

ax.set_xlim(-20,20)
ax.set_ylim(-20,20)
ax.set_zlim(-20,20)
# Out:
# (-20.0, 20.0)

# %%
fig = plt.figure(figsize = (20,20))
for i in range(0,len(ims)-2):
    ax = fig.add_subplot(6,3,i+1)
    plt.imshow(ims[i],cmap='gray')
    ax.scatter(kps[i][:,0],kps[i][:,1],s=2)
